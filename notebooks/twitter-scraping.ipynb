# %% [markdown]
# # Accessing Twitter's APIs

# %%
from configparser import ConfigParser
from babylon.data.twitter import api
import os.path as path
import pandas as pd
from twitter_scraping.twitter_scraping import print_rate_limits, get_users_ids, fetch_tweets
import pickle
import json

# %load_ext autoreload
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Load credentials

# %%
cp = ConfigParser()
cp.read('../.secret/credentials.ini')
# Out:
# ['../.secret/credentials.ini']

# %% [markdown]
# ## Get companies' Twitter ids

# %% [markdown]
# Load the Twitter handles for companies.

# %%
DATA_DIR = "../data/"

# %%
companies_twitter_handles_uk = pd.read_csv(path.join(DATA_DIR, 'companies_twitter_handles_uk.csv'), header=None)
companies_twitter_handles_uk.columns = ['twitter_handle', 'ticker', 'sector']

# %%
companies_twitter_handles_uk.head()
# Out:
#                    twitter_handle ticker             sector
# 0                              3i    III  FinancialServices
# 1                3iInfrastructure    3IN                NaN
# 2                     888Holdings    888                NaN
# 3                              AA    AA.                NaN
# 4  AberforthSmallerCompaniesTrust    ASL                NaN

# %%
twitter_ids_dict = {}

# %%
# twitter_ids_dict.update(session.screen_names_to_user_id(list(companies_twitter_handles_ema.iloc[3:5]['twitter_handle'].values)))

# %%
companies_twitter_handles_uk_list = list(companies_twitter_handles_uk['twitter_handle'].values)

# %% [markdown]
# Instantiate a session.

# %%
session = api.Session(
    consumer_key = cp['emas_twitter_credentials']['consumer_key'],
    consumer_secret = cp['emas_twitter_credentials']['consumer_secret'],
    access_token = cp['emas_twitter_credentials']['access_token'],
    access_token_secret = cp['emas_twitter_credentials']['access_token_secret']
)

# %% [markdown]
# Fetch user ids from the Twitter API and put them in a dictionary.

# %%
get_users_ids(session, companies_twitter_handles_uk_list, twitter_ids_dict)
# Out:
# Fetching 350 ids
# Fetching id: @3i
# Fetching id: @3iInfrastructure
#
# Fetching id: @888Holdings
# Fetching id: @AA
# Fetching id: @AberforthSmallerCompaniesTrust
#
# Fetching id: @AdmiralGroup
# Fetching id: @Aggreko
# Fetching id: @AllianceTrust
# Fetching id: @Amigo
# Fetching id: @AngloAmerican
# Fetching id: @Antofagasta
# Fetching id: @Ascential
# Fetching id: @AshmoreGroup
# Fetching id: @AshteadGroup
#
# Fetching id: @AssociatedBritishFoods
#
# Fetching id: @Assura
# Fetching id: @AstraZeneca
# Fetching id: @AutoTraderGroup
# Fetching id: @Avast
# Fetching id: @Aveva
#
# Fetching id: @Aviva
# Fetching id: @B&MEuropeanRetailValue
#
# Fetching id: @BabcockInternational
#
# Fetching id: @BAESystems
# Fetching id: @BaillieGiffordJapanTrust
#
# Fetching id: @Bakkavör
#
# Fetching id: @BalfourBeatty
# Fetching id: @BankersInvestmentTrust
#
# Fetching id: @BankofGeorgia
# Fetching id: @Barclays
# Fetching id: @Barr,A.G.
#
# Fetching id: @BarrattDevelopments
#
# Fetching id: @BBAAviation
# Fetching id: @BBGI
# Fetching id: @BCAMarketplace
# Fetching id: @BeazleyGroup
# Fetching id: @Bellway
# Fetching id: @BerkeleyGroupHoldings
#
# Fetching id: @BHP
# Fetching id: @BigYellowGroup
#
# Fetching id: @BlackRockSmallerCompaniesTrust
#
# Fetching id: @Bodycote
# Fetching id: @BovisHomesGroup
#
# Fetching id: @BP
# Fetching id: @BrewinDolphinHoldings
#
# Fetching id: @BritishAmericanTobacco
#
# Fetching id: @BritishEmpireTrust
#
# Fetching id: @BritishLand
# Fetching id: @Britvic
# Fetching id: @BT
# Fetching id: @BTG
# Fetching id: @Bunzl
# Fetching id: @Burberry
# Fetching id: @CairnEnergy
# Fetching id: @CaledoniaInvestments
#
# Fetching id: @Capita
# Fetching id: @Capital&CountiesProperties
#
# Fetching id: @CardFactory
#
# Fetching id: @CarnivalCorporation
#
# Fetching id: @Centamin
# Fetching id: @Centrica
# Fetching id: @CharterCourtFinancialServices
#
# Fetching id: @Cineworld
# Fetching id: @CityofLondonInvestmentTrust
#
# Fetching id: @Clarkson
# Fetching id: @CloseBrothersGroup
#
# Fetching id: @CLSHoldings
# Fetching id: @Coats
# Fetching id: @Cobham
# Fetching id: @Coca-ColaHBCAG
#
# Fetching id: @CompassGroup
# Fetching id: @Computacenter
# Fetching id: @ContourGlobal
# Fetching id: @ConvaTec
# Fetching id: @CountrysideProperties
#
# Fetching id: @Cranswick
#
# Fetching id: @CrestNicholson
# Fetching id: @CRH
# Fetching id: @CrodaInternational
#
# Fetching id: @CYBG
# Fetching id: @DaejanHoldings
# Fetching id: @DairyCrest
# Fetching id: @DCC
# Fetching id: @DechraPharmaceuticals
#
# Fetching id: @DerwentLondon
# Fetching id: @Diageo
# Fetching id: @Diploma
# Fetching id: @DirectLineGroup
# Fetching id: @DixonsCarphone
# Fetching id: @Domino'sPizza
#
# Fetching id: @DraxGroup
# Fetching id: @DunelmGroup
#
# Fetching id: @easyJet
# Fetching id: @EdinburghDragonTrust
#
# Fetching id: @EdinburghInvestmentTrust
#
# Fetching id: @EiGroup
# Fetching id: @Electrocomponents
#
# Fetching id: @Elementis
# Fetching id: @EnergeanOil&Gas
#
# Fetching id: @EntertainmentOne
#
# Fetching id: @Equiniti
# Fetching id: @Essentra
# Fetching id: @Esure
# Fetching id: @EuromoneyInstitutionalInvestor
#
# Fetching id: @Evraz
# Fetching id: @Experian
# Fetching id: @F&CCommercialPropertyTrust
#
# Fetching id: @F&CGlobalSmallerCompanies
#
# Fetching id: @FDMGroup
# Fetching id: @Ferguson
# Fetching id: @Ferrexpo
# Fetching id: @FidelityChinaSpecialSituations
#
# Fetching id: @FidelityEuropeanValues
#
# Fetching id: @FidelitySpecialValues
#
# Fetching id: @FinsburyGrowth&IncomeTrust
#
# Fetching id: @FirstGroup
# Fetching id: @Fisher,James&Sons
#
# Fetching id: @Foreign&ColonialInvestmentTrust
#
# Fetching id: @Fresnillo
# Fetching id: @G4S
# Fetching id: @GallifordTry
# Fetching id: @GamesWorkshop
# Fetching id: @GCPInfrastructureInvestments
#
# Fetching id: @GenesisEmergingMarketsFund
#
# Fetching id: @Genus
# Fetching id: @GlaxoSmithKline
# Fetching id: @Glencore
# Fetching id: @Go-AheadGroup
#
# Fetching id: @GraftonGroup
# Fetching id: @Grainger
# Fetching id: @GreatPortlandEstates
#
# Fetching id: @GreencoatUKWind
#
# Fetching id: @Greencore
# Fetching id: @GreeneKing
# Fetching id: @Greggs
# Fetching id: @GVCHoldings
# Fetching id: @HalfordsGroup
#
# Fetching id: @Halma
# Fetching id: @Hammerson
# Fetching id: @HarbourVestGlobalPrivateEquity
#
# Fetching id: @HargreavesLansdown
#
# Fetching id: @HastingsGroup
# Fetching id: @Hays
# Fetching id: @HeraldInvestmentTrust
#
# Fetching id: @HgCapitalTrust
# Fetching id: @HICLInfrastructureCompany
#
# Fetching id: @HikmaPharmaceuticals
#
# Fetching id: @Hill&Smith
#
# Fetching id: @HiltonFoodGroup
#
# Fetching id: @Hiscox
#
# Fetching id: @HochschildMining
#
# Fetching id: @Homeserve
# Fetching id: @HowdenJoinery
# Fetching id: @HSBC
# Fetching id: @Hunting
# Fetching id: @Ibstock
#
# Fetching id: @IGGroupHoldings
#
# Fetching id: @IMI
#
# Fetching id: @ImperialBrands
# Fetching id: @Inchcape
# Fetching id: @Indivior
# Fetching id: @Informa
# Fetching id: @Inmarsat
# Fetching id: @IntegraFinHoldings
#
# Fetching id: @InterContinentalHotelsGroup
#
# Fetching id: @IntermediateCapitalGroup
#
# Fetching id: @InternationalAirlinesGroup
#
# Fetching id: @InternationalPublicPartnerships
#
# Fetching id: @Intertek
# Fetching id: @IntuProperties
# Fetching id: @Investec
# Fetching id: @IPGroup
# Fetching id: @ITV
# Fetching id: @IWG
# Fetching id: @JardineLloydThompson
#
# Fetching id: @JDSports
# Fetching id: @JohnLaingGroup
#
# Fetching id: @JohnsonMatthey
# Fetching id: @JPMorganAmericanInvestmentTrust
#
# Fetching id: @JPMorganEmergingMarketsInvestmentTrust
#
# Fetching id: @JPMorganIndianInvestmentTrust
#
# Fetching id: @JPMorganJapaneseInvestmentTrust
#
# Fetching id: @JupiterEuropeanOpportunitiesTrust
#
# Fetching id: @JupiterFundManagement
#
# Fetching id: @JustEat
#
# Fetching id: @JustGroup
# Fetching id: @KAZMinerals
#
# Fetching id: @KellerGroup
# Fetching id: @KierGroup
# Fetching id: @Kingfisher
# Fetching id: @LancashireHoldings
#
# Fetching id: @LandSecurities
# Fetching id: @Legal&General
#
# Fetching id: @LloydsBankingGroup
#
# Fetching id: @LondonMetricProperty
#
# Fetching id: @LondonStockExchangeGroup
#
# Fetching id: @ManGroup
# Fetching id: @Marks&Spencer
#
# Fetching id: @Marshalls
# Fetching id: @MediclinicInternational
#
# Fetching id: @Meggitt
# Fetching id: @MelroseIndustries
#
# Fetching id: @MercantileInvestmentTrust
#
# Fetching id: @MerlinEntertainments
#
# Fetching id: @MetroBank
# Fetching id: @MicroFocus
# Fetching id: @Millennium&CopthorneHotels
#
# Fetching id: @Mitchells&Butlers
#
# Fetching id: @Mondi
# Fetching id: @Moneysupermarket.comGroup
#
# Fetching id: @MonksInvestmentTrust
#
# Fetching id: @MorganAdvancedMaterials
#
# Fetching id: @Morrisons
# Fetching id: @MurrayInternationalTrust
#
# Fetching id: @NationalExpressGroup
#
# Fetching id: @NationalGrid
# Fetching id: @NBGlobal
# Fetching id: @NewRiver
# Fetching id: @NEXGroup
# Fetching id: @Next
# Fetching id: @NMCHealth
#
# Fetching id: @Ocado
# Fetching id: @OneSavingsBank
#
# Fetching id: @OntheBeach
# Fetching id: @PaddyPowerBetfair
#
# Fetching id: @PageGroup
# Fetching id: @PantheonInternational
#
# Fetching id: @ParagonBankingGroup
#
# Fetching id: @Pearson
# Fetching id: @PennonGroup
# Fetching id: @PerpetualIncome&GrowthInvestmentTrust
#
# Fetching id: @PershingSquareHoldings
#
# Fetching id: @Persimmon
# Fetching id: @PersonalAssetsTrust
#
# Fetching id: @Petrofac
#
# Fetching id: @PhoenixGroupHoldings
#
# Fetching id: @Playtech
# Fetching id: @Plus500
# Fetching id: @PolarCapitalTechnologyTrust
#
# Fetching id: @PolymetalInternational
#
# Fetching id: @Polypipe
# Fetching id: @PremierOil
# Fetching id: @PrimaryHealthProperties
#
# Fetching id: @ProvidentFinancial
#
# Fetching id: @Prudential
# Fetching id: @PZCussons
#
# Fetching id: @QinetiQ
# Fetching id: @Quilter
# Fetching id: @RandgoldResources
#
# Fetching id: @RankGroup
# Fetching id: @RathboneBrothers
#
# Fetching id: @ReckittBenckiser
#
# Fetching id: @Redrow
#
# Fetching id: @RELX
# Fetching id: @RenewablesInfrastructureGroup
#
# Fetching id: @Renishaw
#
# Fetching id: @RentokilInitial
# Fetching id: @RHIMagnesita
#
# Fetching id: @Rightmove
# Fetching id: @RioTinto
# Fetching id: @RITCapitalPartners
#
# Fetching id: @RiverstoneEnergy
#
# Fetching id: @Rolls-RoyceHoldings
#
# Fetching id: @Rotork
# Fetching id: @RoyalBankofScotland
#
# Fetching id: @RoyalDutchShell
# Fetching id: @RoyalMail
# Fetching id: @RPCGroup
# Fetching id: @RSAInsurance
# Fetching id: @Safestore
# Fetching id: @Saga
# Fetching id: @Sage
# Fetching id: @Sainsbury's
#
# Fetching id: @SanneGroup
# Fetching id: @Savills
# Fetching id: @SchroderAsiaPacificFund
#
# Fetching id: @Schroders
# Fetching id: @ScottishInvestmentTrust
#
# Fetching id: @ScottishMortgageInvestmentTrust
#
# Fetching id: @Segro
# Fetching id: @Senior
# Fetching id: @SequoiaEconomicInfrastructureIncomeFund
# Fetching id: @Serco
# Fetching id: @SevernTrent
# Fetching id: @Shaftesbury
# Fetching id: @Shire
# Fetching id: @SIG
# Fetching id: @SiriusMinerals
# Fetching id: @Smith,D.S.
#
# Fetching id: @Smith&Nephew
#
# Fetching id: @Smiths
# Fetching id: @SmurfitKappa
# Fetching id: @Softcat
# Fetching id: @Sophos
# Fetching id: @Spectris
# Fetching id: @Spirax-SarcoEngineering
#
# Fetching id: @SpireHealthcare
# Fetching id: @Spirent
# Fetching id: @SportsDirect
# Fetching id: @SSE
# Fetching id: @SSPGroup
# Fetching id: @St.James'sPlace
#
# Fetching id: @St.ModwenProperties
#
# Fetching id: @StagecoachGroup
# Fetching id: @StandardChartered
#
# Fetching id: @StandardLifeAberdeen
#
# Fetching id: @Stobart
# Fetching id: @Superdry
# Fetching id: @Syncona
# Fetching id: @Synthomer
# Fetching id: @TalkTalkGroup
# Fetching id: @Tate&Lyle
#
# Fetching id: @TaylorWimpey
# Fetching id: @TBCBank
# Fetching id: @TedBaker
# Fetching id: @TelecomPlus
# Fetching id: @TempleBarInvestmentTrust
#
# Fetching id: @TempletonEmergingMarketsInvestmentTrust
#
# Fetching id: @Tesco
# Fetching id: @ThomasCookGroup
#
# Fetching id: @TIFluidSystems
#
# Fetching id: @TPICAP
#
# Fetching id: @TravisPerkins
# Fetching id: @TritaxBigBoxREIT
#
# Fetching id: @TRPropertyInvestmentTrust
#
# Fetching id: @TUIGroup
# Fetching id: @TullowOil
# Fetching id: @UDGHealthcare
# Fetching id: @UKCommercialPropertyTrust
#
# Fetching id: @UltraElectronicsHoldings
#
# Fetching id: @Unilever
# Fetching id: @UnitedUtilities
# Fetching id: @UniteGroup
# Fetching id: @Vesuvius
# Fetching id: @Victrex
# Fetching id: @VietnamEnterpriseInvestments
#
# Fetching id: @VinaCapitalVietnamOpportunityFund
#
# Fetching id: @VivoEnergy
# Fetching id: @VodafoneGroup
# Fetching id: @WeirGroup
# Fetching id: @Wetherspoon(JD)
#
# Fetching id: @Whitbread
# Fetching id: @WHSmith
# Fetching id: @WilliamHill
# Fetching id: @WitanInvestmentTrust
#
# Fetching id: @WizzAir
# Fetching id: @WoodGroup
#
# Fetching id: @WorkspaceGroup
# Fetching id: @WorldwideHealthcareTrust
#
# Fetching id: @WPP

# %%
print_rate_limits(session)
# Out:
# /application/rate_limit_status
# {'limit': 180, 'remaining': 172, 'reset': 1539783420}
# /users/show/:id
# {'limit': 900, 'remaining': 624, 'reset': 1539783403}

# %%
# with open(path.join(DATA_DIR, 'companies_twitter_ids.json'), 'w') as f:
#     json.dump(twitter_ids_dict, f)

# %% [markdown]
# ## Dowloading the tweets from companies

# %%
twitter_ids_dict
# Out:
# {'3i': 18563305,
#  '888Holdings': 203915171,
#  'AA': 13174,
#  'AdmiralGroup': 22493473,
#  'Aggreko': 19020957,
#  'AllianceTrust': 28003164,
#  'Amigo': 14804593,
#  'AngloAmerican': 373538175,
#  'Antofagasta': 18426081,
#  'Ascential': 21120521,
#  'AshmoreGroup': 98700939,
#  'Assura': 33819235,
#  'AstraZeneca': 62465691,
#  'AutoTraderGroup': 622274545,
#  'Avast': 14495718,
#  'Aviva': 1708731,
#  'BAESystems': 723200498635927552,
#  'BalfourBeatty': 295763337,
#  'BankofGeorgia': 191017175,
#  'Barclays': 191781601,
#  'BBAAviation': 408409800,
#  'BBGI': 46869547,
#  'BCAMarketplace': 3355031530,
#  'BeazleyGroup': 44608736,
#  'Bellway': 281591907,
#  'BHP': 2220388494,
#  'Bodycote': 55035772,
#  'BP': 10846,
#  'BritishLand': 3212458450,
#  'Britvic': 227349294,
#  'BT': 432093,
#  'BTG': 264260166,
#  'Bunzl': 17275482,
#  'Burberry': 47459700,
#  'CairnEnergy': 359972154,
#  'Capita': 14384920,
#  'Centamin': 896699000778313728,
#  'Centrica': 15379739,
#  'Cineworld': 17679727,
#  'Clarkson': 6013572,
#  'CLSHoldings': 1479279486,
#  'Coats': 131906765,
#  'Cobham': 2716047620,
#  'CompassGroup': 16325674,
#  'Computacenter': 1037369054888189953,
#  'ContourGlobal': 482060634,
#  'ConvaTec': 925078123204489216,
#  'CrestNicholson': 97639440,
#  'CRH': 17394761,
#  'CYBG': 222349818,
#  'DaejanHoldings': 747732656,
#  'DairyCrest': 18193081,
#  'DCC': 13653092,
#  'DerwentLondon': 412360963,
#  'Diageo': 3033821963,
#  'Diploma': 17418348,
#  'DirectLineGroup': 314029358,
#  'DixonsCarphone': 1364185838,
#  'DraxGroup': 1252648130,
#  'easyJet': 38676903,
#  'EiGroup': 162067651,
#  'Elementis': 180833064,
#  'Equiniti': 2331981374,
#  'Essentra': 597875501,
#  'Esure': 20693066,
#  'Evraz': 479453325,
#  'Experian': 132518473,
#  'FDMGroup': 181923786,
#  'Ferguson': 11141952,
#  'Ferrexpo': 249695629,
#  'FirstGroup': 4894762193,
#  'Fresnillo': 19809215,
#  'G4S': 153369381,
#  'GallifordTry': 270276098,
#  'GamesWorkshop': 15765655,
#  'Genus': 14862912,
#  'GlaxoSmithKline': 89454253,
#  'Glencore': 14831515,
#  'GraftonGroup': 3307365047,
#  'Grainger': 155541003,
#  'Greencore': 212200517,
#  'GreeneKing': 351812643,
#  'Greggs': 5880252,
#  'GVCHoldings': 888340521688739841,
#  'Halma': 21298706,
#  'Hammerson': 91214474,
#  'HastingsGroup': 2493578480,
#  'Hays': 14131546,
#  'HgCapitalTrust': 3307080119,
#  'Homeserve': 269708066,
#  'HowdenJoinery': 91811972,
#  'HSBC': 467368287,
#  'Hunting': 2569271,
#  'ImperialBrands': 21746573,
#  'Inchcape': 18881982,
#  'Indivior': 740298799986446336,
#  'Informa': 280435715,
#  'Inmarsat': 22968823,
#  'Intertek': 177201816,
#  'IntuProperties': 1090087832,
#  'Investec': 323092158,
#  'IPGroup': 46075054,
#  'ITV': 86925202,
#  'IWG': 14166922,
#  'JDSports': 2805156282,
#  'JohnsonMatthey': 72679932,
#  'JustGroup': 188956220,
#  'KellerGroup': 4601413219,
#  'KierGroup': 233963420,
#  'Kingfisher': 7456242,
#  'LandSecurities': 862988785377828869,
#  'ManGroup': 192912869,
#  'Marshalls': 15458197,
#  'Meggitt': 1920485928,
#  'MetroBank': 3600243192,
#  'MicroFocus': 19936330,
#  'Mondi': 2448901,
#  'Morrisons': 224168895,
#  'NationalGrid': 1192665187,
#  'NBGlobal': 165339250,
#  'NewRiver': 2240167902,
#  'NEXGroup': 267734913,
#  'Next': 151251568,
#  'Ocado': 20155502,
#  'OntheBeach': 15781481,
#  'PageGroup': 2330813278,
#  'Pearson': 15146163,
#  'PennonGroup': 368840155,
#  'Persimmon': 13035932,
#  'Playtech': 10225242,
#  'Plus500': 149833456,
#  'Polypipe': 68795178,
#  'PremierOil': 389611538,
#  'Prudential': 1194947442,
#  'QinetiQ': 125598398,
#  'Quilter': 334596167,
#  'RankGroup': 89898609,
#  'RELX': 7863572,
#  'RentokilInitial': 17248862,
#  'Rightmove': 2911111,
#  'RioTinto': 14472978,
#  'Rotork': 19711518,
#  'RoyalDutchShell': 20672315,
#  'RoyalMail': 96965958,
#  'RPCGroup': 17181691,
#  'RSAInsurance': 19975743,
#  'Safestore': 20008254,
#  'Saga': 3392631,
#  'Sage': 6014,
#  'SanneGroup': 368409612,
#  'Savills': 36380487,
#  'Schroders': 109485601,
#  'Segro': 17211998,
#  'Senior': 6627172,
#  'Serco': 16173895,
#  'SevernTrent': 32387239,
#  'Shaftesbury': 18558977,
#  'Shire': 15500775,
#  'SIG': 955211,
#  'SiriusMinerals': 472710628,
#  'Smiths': 14357058,
#  'SmurfitKappa': 430501404,
#  'Softcat': 277457418,
#  'Sophos': 161038997,
#  'Spectris': 50318990,
#  'SpireHealthcare': 93895312,
#  'Spirent': 23594987,
#  'SportsDirect': 23751233,
#  'SSE': 67342845,
#  'SSPGroup': 1008620778638729216,
#  'StagecoachGroup': 129764070,
#  'Stobart': 16844839,
#  'Superdry': 47477421,
#  'Syncona': 78790029,
#  'Synthomer': 1923303211,
#  'TalkTalkGroup': 2543333156,
#  'TaylorWimpey': 60333916,
#  'TBCBank': 128573140,
#  'TedBaker': 1436361,
#  'TelecomPlus': 951639354,
#  'Tesco': 271986064,
#  'TravisPerkins': 30103864,
#  'TUIGroup': 41062336,
#  'TullowOil': 138391611,
#  'UDGHealthcare': 1728188935,
#  'Unilever': 109224937,
#  'UnitedUtilities': 20982364,
#  'UniteGroup': 586428501,
#  'Vesuvius': 238718474,
#  'Victrex': 40329515,
#  'VivoEnergy': 1362152700,
#  'VodafoneGroup': 466341559,
#  'WeirGroup': 1946214092,
#  'Whitbread': 14574541,
#  'WHSmith': 25273394,
#  'WilliamHill': 16667278,
#  'WizzAir': 624837541,
#  'WorkspaceGroup': 88697845,
#  'WPP': 19186720}

# %% [markdown]
# Create tweets dataframe (done already, from the second run on just load the saved one).

# %%
# columns = ['twitter_id',
#  'created_at',
#  'twitter_handle',
#  'twitter_user_id',
#  'text',
#  'is_retweet',
#  'retweet_count',
#  'favorite_count']

# tweets_df = pd.DataFrame(columns=columns)

# %% [markdown]
# Open the tweets dataframe, fetch tweets and append them to it!

# %%
with open(path.join(DATA_DIR, 'tweets_df.pkl'), 'rb') as f:
    tweets_df = pickle.load(f)

# %%
# %autoreload 2

tweets_df = fetch_tweets(session, twitter_ids_dict, tweets_df)
# Out:
# Fetching tweets: 3i
# since_id=None
# Fetching tweets: 888Holdings
# since_id=63599074531749889
# Fetching tweets: AA
# since_id=202280502571438081
# Fetching tweets: AdmiralGroup
# since_id=1051798488915283968
# Fetching tweets: Aggreko
# since_id=458867024987308032
# Fetching tweets: AllianceTrust
# since_id=None
# Error: Not authorized.
# Fetching tweets: Amigo
# since_id=811023986041634817
# Fetching tweets: AngloAmerican
# since_id=1052608046269194240
# Fetching tweets: Antofagasta
# since_id=1052360596748812289
# Fetching tweets: Ascential
# since_id=894699799676506112
# Fetching tweets: AshmoreGroup
# since_id=None
# Fetching tweets: Assura
# since_id=612353168555540480
# Fetching tweets: AstraZeneca
# since_id=1052948361735749633
# Fetching tweets: AutoTraderGroup
# since_id=None
# Fetching tweets: Avast
# since_id=975037586598256640
# Fetching tweets: Aviva
# since_id=965381604146327552
# Fetching tweets: BAESystems
# since_id=None
# Error: Not authorized.
# Fetching tweets: BalfourBeatty
# since_id=1052945419293081600
# Fetching tweets: BankofGeorgia
# since_id=1052888085707526145
# Fetching tweets: Barclays
# since_id=1052941418203934725
# Fetching tweets: BBAAviation
# since_id=None
# Fetching tweets: BBGI
# since_id=None
# Fetching tweets: BCAMarketplace
# since_id=None
# Fetching tweets: BeazleyGroup
# since_id=1052898685158350848
# Fetching tweets: Bellway
# since_id=None
# Fetching tweets: BHP
# since_id=1052832030403125248
# Fetching tweets: Bodycote
# since_id=None
# Fetching tweets: BP
# since_id=923252764121206784
# Fetching tweets: BritishLand
# since_id=672031620006850561
# Fetching tweets: Britvic
# since_id=1052883834835009537
# Fetching tweets: BT
# since_id=1052781240712134657
# Fetching tweets: BTG
# since_id=1051835395829313536
# Fetching tweets: Bunzl
# since_id=None
# Fetching tweets: Burberry
# since_id=1052952623215726592
# Fetching tweets: CairnEnergy
# since_id=1046682746523922432
# Fetching tweets: Capita
# since_id=661499567561535488
# Fetching tweets: Centamin
# since_id=None
# Fetching tweets: Centrica
# since_id=None
# Fetching tweets: Cineworld
# since_id=1052861848029032448
# Fetching tweets: Clarkson
# since_id=992269326089502721
# Fetching tweets: CLSHoldings
# since_id=1045613771862016000
# Fetching tweets: Coats
# since_id=None
# Fetching tweets: Cobham
# since_id=557275836936486912
# Fetching tweets: CompassGroup
# since_id=None
# Fetching tweets: Computacenter
# since_id=None
# Error: Not authorized.
# Fetching tweets: ContourGlobal
# since_id=165432003989221377
# Fetching tweets: ConvaTec
# since_id=925079769074593792
# Fetching tweets: CrestNicholson
# since_id=1052892821106188288
# Fetching tweets: CRH
# since_id=1052913609758642177
# Fetching tweets: CYBG
# since_id=None
# Fetching tweets: DaejanHoldings
# since_id=None
# Fetching tweets: DairyCrest
# since_id=None
# Fetching tweets: DCC
# since_id=1052301447373737984
# Fetching tweets: DerwentLondon
# since_id=1052488168853958657
# Fetching tweets: Diageo
# since_id=None
# Fetching tweets: Diploma
# since_id=None
# Error: Not authorized.
# Fetching tweets: DirectLineGroup
# since_id=88972496312860673
# Fetching tweets: DixonsCarphone
# since_id=1051015934561964032
# Fetching tweets: DraxGroup
# since_id=None
# Error: Not authorized.
# Fetching tweets: easyJet
# since_id=1050706990161424384
# Fetching tweets: EiGroup
# since_id=None
# Fetching tweets: Elementis
# since_id=355850699701104641
# Fetching tweets: Equiniti
# since_id=1052922342677073920
# Fetching tweets: Essentra
# since_id=221766463147614210
# Fetching tweets: Esure
# since_id=None
# Error: Not authorized.
# Fetching tweets: Evraz
# since_id=None
# Fetching tweets: Experian
# since_id=1052938881262219264
# Fetching tweets: FDMGroup
# since_id=1052947362845470731
# Fetching tweets: Ferguson
# since_id=1035540433030529025
# Fetching tweets: Ferrexpo
# since_id=None
# Fetching tweets: FirstGroup
# since_id=None
# Fetching tweets: Fresnillo
# since_id=974537737935110145
# Fetching tweets: G4S
# since_id=1052497473183371264
# Fetching tweets: GallifordTry
# since_id=1052922432003207168
# Fetching tweets: GamesWorkshop
# since_id=10519302035
# Fetching tweets: Genus
# since_id=1052870697435967488
# Fetching tweets: GlaxoSmithKline
# since_id=None
# Error: Not authorized.
# Fetching tweets: Glencore
# since_id=1052911437432147971
# Fetching tweets: GraftonGroup
# since_id=878046696340463617
# Fetching tweets: Grainger
# since_id=1052943389690347520
# Fetching tweets: Greencore
# since_id=None
# Error: Not authorized.
# Fetching tweets: GreeneKing
# since_id=1052595288295333889
# Fetching tweets: Greggs
# since_id=None
# Error: Not authorized.
# Fetching tweets: GVCHoldings
# since_id=None
# Fetching tweets: Halma
# since_id=1226648288
# Fetching tweets: Hammerson
# since_id=944379119537676288
# Fetching tweets: HastingsGroup
# since_id=671773663939698688
# Fetching tweets: Hays
# since_id=12018545722396672
# Fetching tweets: HgCapitalTrust
# since_id=1039037470799790080
# Fetching tweets: Homeserve
# since_id=None
# Fetching tweets: HowdenJoinery
# since_id=None
# Fetching tweets: HSBC
# since_id=1052522241597104128
# Fetching tweets: Hunting
# since_id=None
# Fetching tweets: ImperialBrands
# since_id=1052510263470149632
# Fetching tweets: Inchcape
# since_id=964666255042056192
# Fetching tweets: Indivior
# since_id=None
# Error: Not authorized.
# Fetching tweets: Informa
# since_id=1052922449661186048
# Fetching tweets: Inmarsat
# since_id=None
# Fetching tweets: Intertek
# since_id=1052952924937175042
# Fetching tweets: IntuProperties
# since_id=389705902481104896
# Fetching tweets: Investec
# since_id=1052918176789536768
# Fetching tweets: IPGroup
# since_id=2101462663
# Fetching tweets: ITV
# since_id=1052937882686644224
# Fetching tweets: IWG
# since_id=1052156176610222081
# Fetching tweets: JDSports
# since_id=1052472638801633280
# Fetching tweets: JohnsonMatthey
# since_id=None
# Fetching tweets: JustGroup
# since_id=24058428807
# Fetching tweets: KellerGroup
# since_id=1027515731439546369
# Fetching tweets: KierGroup
# since_id=1052948321617240064
# Fetching tweets: Kingfisher
# since_id=148569702
# Fetching tweets: LandSecurities
# since_id=None
# Error: Not authorized.
# Fetching tweets: ManGroup
# since_id=1052599458196807685
# Fetching tweets: Marshalls
# since_id=1044373556455510016
# Fetching tweets: Meggitt
# since_id=391178414323150848
# Fetching tweets: MetroBank
# since_id=None
# Fetching tweets: MicroFocus
# since_id=1052846767467888641
# Fetching tweets: Mondi
# since_id=None
# Error: Not authorized.
# Fetching tweets: Morrisons
# since_id=1052583262126661632
# Fetching tweets: NationalGrid
# since_id=None
# Fetching tweets: NBGlobal
# since_id=None
# Fetching tweets: NewRiver
# since_id=986739002525954048
# Fetching tweets: NEXGroup
# since_id=None
# Fetching tweets: Next
# since_id=None
# Error: Not authorized.
# Fetching tweets: Ocado
# since_id=1052877369730617344
# Fetching tweets: OntheBeach
# since_id=567791545098739712
# Fetching tweets: PageGroup
# since_id=431897008153313280
# Fetching tweets: Pearson
# since_id=1052710860165181440
# Fetching tweets: PennonGroup
# since_id=1052952708930514944
# Fetching tweets: Persimmon
# since_id=None
# Error: Not authorized.
# Fetching tweets: Playtech
# since_id=49619635074646016
# Fetching tweets: Plus500
# since_id=1052828507389288448
# Fetching tweets: Polypipe
# since_id=336940461770014720
# Fetching tweets: PremierOil
# since_id=189045747965116416
# Fetching tweets: Prudential
# since_id=1052257096702550016
# Fetching tweets: QinetiQ
# since_id=1052803993485889536
# Fetching tweets: Quilter
# since_id=1027220745829666816
# Fetching tweets: RankGroup
# since_id=90712883389927424
# Fetching tweets: RELX
# since_id=179284662
# Fetching tweets: RentokilInitial
# since_id=1047479124518998016
# Fetching tweets: Rightmove
# since_id=1052956591278960640
# Fetching tweets: RioTinto
# since_id=1051951949145346053
# Fetching tweets: Rotork
# since_id=1052944900675788800
# Fetching tweets: RoyalDutchShell
# since_id=29655551239
# Fetching tweets: RoyalMail
# since_id=1052959011589513216
# Fetching tweets: RPCGroup
# since_id=991021916
# Fetching tweets: RSAInsurance
# since_id=None
# Error: Not authorized.
# Fetching tweets: Safestore
# since_id=1186330248
# Fetching tweets: Saga
# since_id=1012318543491166210
# Fetching tweets: Sage
# since_id=1020531074299056128
# Fetching tweets: SanneGroup
# since_id=1052477983959773185
# Fetching tweets: Savills
# since_id=1052895879370350593
# Fetching tweets: Schroders
# since_id=1052902568215621632
# Fetching tweets: Segro
# since_id=350346962962354176
# Fetching tweets: Senior
# since_id=1051274401713410048
# Fetching tweets: Serco
# since_id=None
# Fetching tweets: SevernTrent
# since_id=None
# Fetching tweets: Shaftesbury
# since_id=None
# Fetching tweets: Shire
# since_id=841195334176931840
# Fetching tweets: SIG
# since_id=707621429571932160
# Fetching tweets: SiriusMinerals
# since_id=1052887642323476480
# Fetching tweets: Smiths
# since_id=786850662
# Fetching tweets: SmurfitKappa
# since_id=1052819528885911554
# Fetching tweets: Softcat
# since_id=1052953271361519618
# Fetching tweets: Sophos
# since_id=1052958790839140357
# Fetching tweets: Spectris
# since_id=None
# Error: Not authorized.
# Fetching tweets: SpireHealthcare
# since_id=1052862227521433600
# Fetching tweets: Spirent
# since_id=1052942653015379969
# Fetching tweets: SportsDirect
# since_id=497772881473196032
# Fetching tweets: SSE
# since_id=1052927460990472195
# Fetching tweets: SSPGroup
# since_id=1010041785975033857
# Fetching tweets: StagecoachGroup
# since_id=1052937735655305216
# Fetching tweets: Stobart
# since_id=None
# Fetching tweets: Superdry
# since_id=1052937354393071618
# Fetching tweets: Syncona
# since_id=None
# Error: Not authorized.
# Fetching tweets: Synthomer
# since_id=457839666499420160
# Fetching tweets: TalkTalkGroup
# since_id=1039525962176757761
# Fetching tweets: TaylorWimpey
# since_id=1052914766845493248
# Fetching tweets: TBCBank
# since_id=None
# Fetching tweets: TedBaker
# since_id=834839426
# Fetching tweets: TelecomPlus
# since_id=None
# Fetching tweets: Tesco
# since_id=1052975097257058305
# Fetching tweets: TravisPerkins
# since_id=1030565194752086016
# Fetching tweets: TUIGroup
# since_id=1052870184430493703
# Fetching tweets: TullowOil
# since_id=66428588387344384
# Fetching tweets: UDGHealthcare
# since_id=1052953551335542785
# Fetching tweets: Unilever
# since_id=1052876241349558272
# Fetching tweets: UnitedUtilities
# since_id=1052981078816886785
# Fetching tweets: UniteGroup
# since_id=1051842656404422656
# Fetching tweets: Vesuvius
# since_id=506353272848801793
# Fetching tweets: Victrex
# since_id=958990599083917312
# Fetching tweets: VivoEnergy
# since_id=1052884619320840192
# Fetching tweets: VodafoneGroup
# since_id=1052893053185388544
# Fetching tweets: WeirGroup
# since_id=1052047641901768704
# Fetching tweets: Whitbread
# since_id=798972243
# Fetching tweets: WHSmith
# since_id=1052986531202433024
# Fetching tweets: WilliamHill
# since_id=1052948186174803969
# Fetching tweets: WizzAir
# since_id=1052832225492967424
# Fetching tweets: WorkspaceGroup
# since_id=1052926277609562112
# Fetching tweets: WPP
# since_id=1052982044790284288

# %%
tweets_df['twitter_handle'].unique()
# Out:
# array(['Avast', '888Holdings', 'AA', 'AdmiralGroup', 'Aggreko', 'Amigo',
#        'AngloAmerican', 'Antofagasta', 'Ascential', 'Assura',
#        'AstraZeneca', 'Aviva', 'BalfourBeatty', 'BankofGeorgia',
#        'Barclays', 'BeazleyGroup', 'BHP', 'BP', 'BritishLand', 'Britvic',
#        'BT', 'BTG', 'Burberry', 'CairnEnergy', 'Capita', 'Cineworld',
#        'Clarkson', 'CLSHoldings', 'Cobham', 'ContourGlobal', 'ConvaTec',
#        'CrestNicholson', 'CRH', 'DCC', 'DerwentLondon', 'DirectLineGroup',
#        'DixonsCarphone', 'easyJet', 'Elementis', 'Equiniti', 'Essentra',
#        'Experian', 'FDMGroup', 'Ferguson', 'Fresnillo', 'G4S',
#        'GallifordTry', 'GamesWorkshop', 'Genus', 'Glencore',
#        'GraftonGroup', 'Grainger', 'GreeneKing', 'Halma', 'Hammerson',
#        'HastingsGroup', 'Hays', 'HgCapitalTrust', 'HSBC',
#        'ImperialBrands', 'Inchcape', 'Informa', 'Intertek',
#        'IntuProperties', 'Investec', 'IPGroup', 'ITV', 'IWG', 'JDSports',
#        'JustGroup', 'KellerGroup', 'KierGroup', 'Kingfisher', 'ManGroup',
#        'Marshalls', 'Meggitt', 'MicroFocus', 'Morrisons', 'NewRiver',
#        'Ocado', 'OntheBeach', 'PageGroup', 'Pearson', 'PennonGroup',
#        'Playtech', 'Plus500', 'Polypipe', 'PremierOil', 'Prudential',
#        'QinetiQ', 'Quilter', 'RankGroup', 'RELX', 'RentokilInitial',
#        'Rightmove', 'RioTinto', 'Rotork', 'RoyalDutchShell', 'RoyalMail',
#        'RPCGroup', 'Safestore', 'Saga', 'Sage', 'SanneGroup', 'Savills',
#        'Schroders', 'Segro', 'Senior', 'Shire', 'SIG', 'SiriusMinerals',
#        'Smiths', 'SmurfitKappa', 'Softcat', 'Sophos', 'SpireHealthcare',
#        'Spirent', 'SportsDirect', 'SSE', 'SSPGroup', 'StagecoachGroup',
#        'Superdry', 'Synthomer', 'TalkTalkGroup', 'TaylorWimpey',
#        'TedBaker', 'Tesco', 'TravisPerkins', 'TUIGroup', 'TullowOil',
#        'UDGHealthcare', 'Unilever', 'UnitedUtilities', 'UniteGroup',
#        'Vesuvius', 'Victrex', 'VivoEnergy', 'VodafoneGroup', 'WeirGroup',
#        'Whitbread', 'WHSmith', 'WilliamHill', 'WizzAir', 'WorkspaceGroup',
#        'WPP'], dtype=object)

# %%
len(tweets_df['twitter_handle'].unique())
# Out:
# 145

# %%
tweets_df.shape
# Out:
# (156731, 8)

# %%
print_rate_limits(session)
# Out:
# /application/rate_limit_status
# {'limit': 180, 'remaining': 179, 'reset': 1539945199}

# %%
# with open(path.join(DATA_DIR, 'tweets_df.pkl'), 'wb') as f:
#     pickle.dump(tweets_df, f)

# %% [markdown]
# ## Access the Search API(s)

# %% [markdown]
# Instantiate session.

# %% [markdown]
# Querying the Search API. The query must be formatted in a particular way (see: https://developer.twitter.com/en/docs/tweets/search/guides/standard-operators).

# %%
query = "salvini"

tweets = session.tweets_search(
    query
)
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# /opt/anaconda/envs/Python3/lib/python3.6/site-packages/babylon/data/twitter/api.py in trial(num_retries, *args, **kwargs)
#      31         try:
# ---> 32             return api_function(*args, **kwargs)
#      33         except tweepy.error.RateLimitError:
#
# /opt/anaconda/envs/Python3/lib/python3.6/site-packages/babylon/data/twitter/api.py in _search(self, query, max_id, since_id, lang, count, tweet_mode)
#     277             q=query, max_id=max_id, since_id=since_id, lang=lang, count=count,
# --> 278             tweet_mode=tweet_mode
#     279         )
#
# /opt/anaconda/envs/Python3/lib/python3.6/site-packages/tweepy/binder.py in _call(*args, **kwargs)
#     249         else:
# --> 250             return method.execute()
#     251
#
# /opt/anaconda/envs/Python3/lib/python3.6/site-packages/tweepy/binder.py in execute(self)
#     231                 if is_rate_limit_error_message(error_msg):
# --> 232                     raise RateLimitError(error_msg, resp)
#     233                 else:
#
# RateLimitError: [{'message': 'Rate limit exceeded', 'code': 88}]
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-12f774223f60> in <module>()
#       2
#       3 tweets = session.tweets_search(
# ----> 4     query
#       5 )
#
# /opt/anaconda/envs/Python3/lib/python3.6/site-packages/babylon/data/twitter/api.py in tweets_search(self, query, max_id, since_id, lang)
#     263                 since_id=since_id,
#     264                 lang=lang,
# --> 265                 tweet_mode='extended'
#     266             )
#     267
#
# /opt/anaconda/envs/Python3/lib/python3.6/site-packages/babylon/data/twitter/api.py in trial(num_retries, *args, **kwargs)
#      39                 )
#      40                 LOGGER.info(msg)
# ---> 41                 time.sleep(API_WAIT_TIME_SECONDS)
#      42                 return trial(*args, num_retries=num_retries+1, **kwargs)
#      43     return trial
#
# KeyboardInterrupt:
